# %%
## Config box

d = {"Key": "val", "Key1": "val1"}

# %%
d["Key"]
# Out:
# 'val'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"Key": "val", "Key1": "val1"})

# %%
d2.Key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
#ensure annotation
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(2,3)
# Out:
# 6

# %%
get_prodict(x=2,y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %% [markdown]
# ## Download the Dataset from google drive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1BCttxlTewnR4zOjDgKJ_Y41F8K6kjaO1/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1BCttxlTewnR4zOjDgKJ_Y41F8K6kjaO1'

# %%
prefix = "https://drive.google.com/uc?export=download&id="  
gdown.download(prefix + file_id, "Kidney-CT-Scan-Dataset.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1BCttxlTewnR4zOjDgKJ_Y41F8K6kjaO1
# From (redirected): https://drive.google.com/uc?export=download&id=1BCttxlTewnR4zOjDgKJ_Y41F8K6kjaO1&confirm=t&uuid=fb135ded-4dc5-4cb0-992a-0a834a8f3c76
# To: d:\PYTHON PROJECTS\MLOPS\Kidney-Disease-Detection\research\Kidney-CT-Scan-Dataset.zip
# 100%|██████████| 925M/925M [08:59<00:00, 1.71MB/s]
# 'Kidney-CT-Scan-Dataset.zip'
